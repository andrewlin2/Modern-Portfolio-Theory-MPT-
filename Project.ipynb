# %% [markdown]
# # Section 1 - Motivation and Background

# %% [markdown]
# # Section 2 - Data and Setup

# %%
import pandas as pd 
company_info = pd.read_csv("fortune1000_2024.csv").head(500) #fortune 1000 companies, we need something to call (yfinance). 

print(company_info.shape)
company_info.head()
# Out:
# (500, 32)
#    Rank             Company Ticker       Sector  \
# 0     1             Walmart    WMT    Retailing
# 1     2              Amazon   AMZN    Retailing
# 2     3               Apple   AAPL   Technology
# 3     4  UnitedHealth Group    UNH  Health Care
# 4     5  Berkshire Hathaway   BRKA   Financials
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# 3   Health Care: Insurance and Managed Care        yes             no
# 4  Insurance: Property and Casualty (Stock)        yes             no
#
#   FemaleCEO Growth_in_Jobs  Change_in_Rank  ...   Assets_M  \
# 0        no             no             0.0  ...   252399.0
# 1        no             no             0.0  ...   527854.0
# 2        no             no             1.0  ...   352583.0
# 3        no            yes             1.0  ...   273720.0
# 4        no            yes             2.0  ...  1069978.0
#
#                    CEO Country HeadquartersCity HeadquartersState  \
# 0  C. Douglas McMillon    U.S.      Bentonville          Arkansas
# 1      Andrew R. Jassy    U.S.          Seattle        Washington
# 2      Timothy D. Cook    U.S.        Cupertino        California
# 3      Andrew P. Witty    U.S.       Minnetonka         Minnesota
# 4    Warren E. Buffett    U.S.            Omaha          Nebraska
#
#                              Website  CompanyType  \
# 0      https://www.stock.walmart.com       Public
# 1             https://www.amazon.com       Public
# 2              https://www.apple.com       Public
# 3  https://www.unitedhealthgroup.com       Public
# 4  https://www.berkshirehathaway.com       Public
#
#                                             Footnote  MarketCap_Updated_M  \
# 0  Figures are for fiscal year ended Jan. 31, 202...             559911.0
# 1                  Market value as of July 15, 2024.            2005565.0
# 2  Figures are for fiscal year ended Sept. 30, 20...            3594309.0
# 3                  Market value as of July 15, 2024.             474339.0
# 4                  Market value as of July 15, 2024.             937028.0
#
#       Updated
# 0  2024-08-05
# 1  2024-08-05
# 2  2024-08-05
# 3  2024-08-05
# 4  2024-08-05
#
# [5 rows x 32 columns]

# %%
# import yfinance as yf  #yahoo finance, call functions that retrive data for me

# # Prepare tickers
# tickers = company_info['Ticker'].dropna().astype(str).tolist() # company_info['Ticker'] is going to return the column that has column name Ticker
#                                 # dropna drops anything that's blank
#                                 #
# # Clean the list to all tickers work with yfinance
# list_to_drop = ['NYCB', 'CLR', 'GPS', 'PXD', 'BECN', 'SQ', 'HES', 'DFS', 'RADCQ', 'SKX', 'QRTEA', 'X', 'WBA', 'LSXMA', 'JWN', 'BERY', 'BRKA', 'SPTN', 'PARA', 'CHK', 'FL','IPG', 'FI', 'AMRK', 'OMI', 'ATUS', 'K', 'ODP', 'MMC']
# for ticker in tickers:
#     if ticker in list_to_drop:
#         tickers.remove(ticker)
# #some tickers in yfinance doesn't work anymore (delisted companies, error in ticker, etc). Removes any of those delisted companies 

# # Download closing prices
# data_2023 = yf.download(tickers, start="2023-01-01", end="2023-12-31")['Close'] # does not have to call yfinance everytime
# data_2024 = yf.download(tickers, start="2024-01-01", end="2024-12-31")['Close'] # we dont have opening price here because 

# data_2023 = data_2023.dropna(axis=1, how='all') # when we get this data, there is extra information we want to drop. <date> <closing>
# data_2024 = data_2024.dropna(axis=1, how='all') # when we get this data, there is extra information we want to drop. <date> <closing>

# returns_2023 = data_2023.pct_change(fill_method=None).dropna() # calculating returns for every stock 
# returns_2024 = data_2024.pct_change(fill_method=None).dropna() # change between closing price and opening price on a trading day

# print(returns_2023.head())
# print(returns_2024.head())

# returns_2023.to_csv("returns_2023.csv")
# returns_2024.to_csv("returns_2024.csv")
# Out:
# [******                12%                       ]  55 of 447 completed$BGST: possibly delisted; no price data found  (1d 2023-01-01 -> 2023-12-31)
# [**********************76%***********            ]  339 of 447 completed$FL: possibly delisted; no timezone found
# [**********************87%*****************      ]  391 of 447 completed$CHK: possibly delisted; no timezone found
# [*********************100%***********************]  447 of 447 completed
#
# 3 Failed downloads:
# ['BGST']: possibly delisted; no price data found  (1d 2023-01-01 -> 2023-12-31)
# ['FL', 'CHK']: possibly delisted; no timezone found
# [******                13%                       ]  58 of 447 completed$BGST: possibly delisted; no price data found  (1d 2024-01-01 -> 2024-12-31)
# [**********************52%                       ]  234 of 447 completed$ULTA: possibly delisted; no price data found  (1d 2024-01-01 -> 2024-12-31)
# [**********************72%**********             ]  323 of 447 completed$FL: possibly delisted; no timezone found
# [**********************84%***************        ]  377 of 447 completed$CHK: possibly delisted; no timezone found
# [*********************100%***********************]  447 of 447 completed
#
# 4 Failed downloads:
# ['BGST', 'ULTA']: possibly delisted; no price data found  (1d 2024-01-01 -> 2024-12-31)
# ['FL', 'CHK']: possibly delisted; no timezone found
# Ticker            AA       AAL       AAP      AAPL      ABBV       ABG  \
# Date
# 2023-01-04  0.012337  0.066719  0.002310  0.010314  0.008067  0.028916
# 2023-01-05  0.007977  0.029433  0.008361 -0.010605 -0.001222  0.005018
# 2023-01-06  0.019125  0.013581  0.005615  0.036794  0.018717  0.022137
# 2023-01-09  0.084340  0.030324 -0.011427  0.004089 -0.029361  0.000054
# 2023-01-10  0.053909  0.039699 -0.001904  0.004457 -0.012495  0.027844
#
# Ticker           ABM      ABNB       ABT       ACI  ...       WSM       WSO  \
# Date                                                ...
# 2023-01-04  0.006491  0.044994  0.014875  0.009662  ...  0.035943  0.020205
# 2023-01-05  0.014454 -0.011384 -0.003687 -0.002392  ... -0.011509 -0.018001
# 2023-01-06  0.012933  0.009235  0.013809 -0.001919  ...  0.059498  0.025249
# 2023-01-09 -0.014499  0.008134 -0.001603  0.005286  ... -0.012848  0.008959
# 2023-01-10  0.014273 -0.007844  0.015158  0.018164  ...  0.028976  0.026600
#
# Ticker            WY       XEL       XOM       XPO       XYL      YUMC  \
# Date
# 2023-01-04  0.011990  0.008563  0.002911  0.032458 -0.001535  0.039525
# 2023-01-05 -0.029779 -0.020235  0.022374  0.018263 -0.028393 -0.010401
# 2023-01-06  0.043234  0.029607  0.012087  0.058218  0.035552 -0.000345
# 2023-01-09 -0.006011  0.009679 -0.018638  0.041400  0.004673  0.016029
# 2023-01-10 -0.017823  0.001806  0.014935 -0.004803  0.010287  0.003732
#
# Ticker           ZBH       ZTS
# Date
# 2023-01-04  0.009271  0.014368
# 2023-01-05 -0.018527 -0.023563
# 2023-01-06 -0.003014  0.015056
# 2023-01-09  0.002784 -0.003928
# 2023-01-10 -0.004363  0.049640
#
# [5 rows x 444 columns]
# Ticker            AA       AAL       AAP      AAPL      ABBV       ABG  \
# Date
# 2024-01-03 -0.054638 -0.036458 -0.015335 -0.007488  0.004005 -0.063588
# 2024-01-04 -0.011432  0.010811 -0.008361 -0.012700  0.006232 -0.008003
# 2024-01-05  0.032123  0.038961  0.017028 -0.004013  0.004211 -0.007053
# 2024-01-08 -0.012449  0.072059  0.006339  0.024175 -0.004379  0.015617
# 2024-01-09  0.006618 -0.013717 -0.008399 -0.002263  0.005451  0.001437
#
# Ticker           ABM      ABNB       ABT       ACI  ...       WSM       WSO  \
# Date                                                ...
# 2024-01-03 -0.020869 -0.007882 -0.003004 -0.005256  ... -0.043087 -0.024764
# 2024-01-04 -0.002304  0.002249  0.013331 -0.007486  ...  0.003290  0.008627
# 2024-01-05 -0.019630  0.016901 -0.001622  0.022183  ...  0.004816 -0.016234
# 2024-01-08  0.002120  0.030152  0.014440 -0.002170  ...  0.016723 -0.002242
# 2024-01-09 -0.009638 -0.003926  0.002936  0.004785  ... -0.003460 -0.001234
#
# Ticker            WY       XEL       XOM       XPO       XYL      YUMC  \
# Date
# 2024-01-03 -0.020983  0.001733  0.008402 -0.027097 -0.018563  0.012017
# 2024-01-04 -0.013799  0.002359 -0.008719 -0.006297  0.006902 -0.019558
# 2024-01-05  0.002679  0.000000  0.003030  0.002559 -0.001602 -0.028022
# 2024-01-08  0.010986 -0.002354 -0.016662  0.013978  0.006242 -0.012949
# 2024-01-09 -0.009104 -0.004876 -0.012386 -0.001079 -0.006557 -0.030693
#
# Ticker           ZBH       ZTS
# Date
# 2024-01-03 -0.007579 -0.018518
# 2024-01-04 -0.002241  0.005753
# 2024-01-05 -0.001830  0.004174
# 2024-01-08  0.016586  0.006672
# 2024-01-09 -0.000820 -0.001071
#
# [5 rows x 443 columns]

# %%
# read the data from the csv files

returns_2023 = pd.read_csv("returns_2023.csv")
returns_2024 = pd.read_csv("returns_2024.csv")

print(returns_2023.head())
print(returns_2024.head())
# Out:
#          Date        AA       AAL       AAP      AAPL      ABBV       ABG  \
# 0  2023-01-04  0.012337  0.066719  0.002310  0.010314  0.008067  0.028916
# 1  2023-01-05  0.007977  0.029433  0.008361 -0.010605 -0.001222  0.005018
# 2  2023-01-06  0.019125  0.013581  0.005615  0.036794  0.018717  0.022137
# 3  2023-01-09  0.084340  0.030324 -0.011427  0.004089 -0.029360  0.000054
# 4  2023-01-10  0.053909  0.039699 -0.001905  0.004456 -0.012495  0.027844
#
#         ABM      ABNB       ABT  ...       WSM       WSO        WY       XEL  \
# 0  0.006491  0.044994  0.014875  ...  0.035943  0.020205  0.011990  0.008563
# 1  0.014454 -0.011384 -0.003687  ... -0.011509 -0.018001 -0.029779 -0.020235
# 2  0.012933  0.009235  0.013809  ...  0.059498  0.025249  0.043234  0.029607
# 3 -0.014499  0.008134 -0.001602  ... -0.012847  0.008959 -0.006011  0.009679
# 4  0.014273 -0.007844  0.015158  ...  0.028976  0.026600 -0.017823  0.001806
#
#         XOM       XPO       XYL      YUMC       ZBH       ZTS
# 0  0.002910  0.032458 -0.001535  0.039525  0.009271  0.014368
# 1  0.022374  0.018263 -0.028393 -0.010401 -0.018527 -0.023564
# 2  0.012087  0.058218  0.035551 -0.000345 -0.003014  0.015057
# 3 -0.018638  0.041400  0.004673  0.016029  0.002784 -0.003928
# 4  0.014935 -0.004803  0.010287  0.003732 -0.004363  0.049640
#
# [5 rows x 445 columns]
#          Date        AA       AAL       AAP      AAPL      ABBV       ABG  \
# 0  2024-01-03 -0.054638 -0.036458 -0.015335 -0.007488  0.004004 -0.063588
# 1  2024-01-04 -0.011432  0.010811 -0.008361 -0.012700  0.006232 -0.008003
# 2  2024-01-05  0.032123  0.038961  0.017028 -0.004013  0.004211 -0.007053
# 3  2024-01-08 -0.012449  0.072059  0.006339  0.024175 -0.004379  0.015617
# 4  2024-01-09  0.006618 -0.013717 -0.008399 -0.002263  0.005452  0.001437
#
#         ABM      ABNB       ABT  ...       WSM       WSO        WY       XEL  \
# 0 -0.020869 -0.007882 -0.003004  ... -0.043087 -0.024764 -0.020983  0.001733
# 1 -0.002304  0.002249  0.013331  ...  0.003290  0.008627 -0.013799  0.002359
# 2 -0.019630  0.016901 -0.001622  ...  0.004816 -0.016235  0.002679  0.000000
# 3  0.002120  0.030152  0.014440  ...  0.016723 -0.002241  0.010986 -0.002354
# 4 -0.009638 -0.003926  0.002936  ... -0.003460 -0.001234 -0.009104 -0.004876
#
#         XOM       XPO       XYL      YUMC       ZBH       ZTS
# 0  0.008402 -0.027097 -0.018563  0.012017 -0.007579 -0.018518
# 1 -0.008719 -0.006297  0.006902 -0.019558 -0.002241  0.005754
# 2  0.003030  0.002559 -0.001602 -0.028022 -0.001830  0.004174
# 3 -0.016662  0.013978  0.006242 -0.012949  0.016586  0.006672
# 4 -0.012386 -0.001079 -0.006557 -0.030693 -0.000820 -0.001071
#
# [5 rows x 445 columns]

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.3.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.13/site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.13/site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/lib/python3.13/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/lib/python3.13/site-packages (from yfinance) (2.4.6)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.0.5-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/lib/python3.13/site-packages (from yfinance) (4.13.5)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.15.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/anaconda3/lib/python3.13/site-packages (from yfinance) (5.29.3)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (2025.11.12)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (14.2.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich->curl_cffi>=0.15->yfinance) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich->curl_cffi>=0.15->yfinance) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)
# Downloading yfinance-1.3.0-py2.py3-none-any.whl (133 kB)
# Downloading curl_cffi-0.15.0-cp310-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 30.7 MB/s  0:00:00
# Downloading multitasking-0.0.13-py3-none-any.whl (16 kB)
# Downloading peewee-4.0.5-py3-none-any.whl (144 kB)
# Downloading websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl (175 kB)
# Installing collected packages: peewee, multitasking, websockets, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [yfinance]━━ 4/5 [yfinance]
# Successfully installed curl_cffi-0.15.0 multitasking-0.0.13 peewee-4.0.5 websockets-16.0 yfinance-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Section 3 - Modern Portfolio Theory (MPT)

# %% [markdown]
# Modern Portfolio Theory (MPT) seeks to find the optimal combination of stocks to created a diversifed portfolio. MPT uses variance as a measure of risk for a stock: The higher the variance, the more volatile the stock is (the more the price fluctuates). It does this by calculating the covariance matrix between between stocks and looking for pairs (x, y) where COV(x, y) is close to -1 signaling that they behave oppositely.

# %%
print(returns_2023.head())
print(returns_2024.head())
# Out:
#          Date        AA       AAL       AAP      AAPL      ABBV       ABG  \
# 0  2023-01-04  0.012337  0.066719  0.002310  0.010314  0.008067  0.028916
# 1  2023-01-05  0.007977  0.029433  0.008361 -0.010605 -0.001222  0.005018
# 2  2023-01-06  0.019125  0.013581  0.005615  0.036794  0.018717  0.022137
# 3  2023-01-09  0.084340  0.030324 -0.011427  0.004089 -0.029360  0.000054
# 4  2023-01-10  0.053909  0.039699 -0.001905  0.004456 -0.012495  0.027844
#
#         ABM      ABNB       ABT  ...       WSM       WSO        WY       XEL  \
# 0  0.006491  0.044994  0.014875  ...  0.035943  0.020205  0.011990  0.008563
# 1  0.014454 -0.011384 -0.003687  ... -0.011509 -0.018001 -0.029779 -0.020235
# 2  0.012933  0.009235  0.013809  ...  0.059498  0.025249  0.043234  0.029607
# 3 -0.014499  0.008134 -0.001602  ... -0.012847  0.008959 -0.006011  0.009679
# 4  0.014273 -0.007844  0.015158  ...  0.028976  0.026600 -0.017823  0.001806
#
#         XOM       XPO       XYL      YUMC       ZBH       ZTS
# 0  0.002910  0.032458 -0.001535  0.039525  0.009271  0.014368
# 1  0.022374  0.018263 -0.028393 -0.010401 -0.018527 -0.023564
# 2  0.012087  0.058218  0.035551 -0.000345 -0.003014  0.015057
# 3 -0.018638  0.041400  0.004673  0.016029  0.002784 -0.003928
# 4  0.014935 -0.004803  0.010287  0.003732 -0.004363  0.049640
#
# [5 rows x 445 columns]
#          Date        AA       AAL       AAP      AAPL      ABBV       ABG  \
# 0  2024-01-03 -0.054638 -0.036458 -0.015335 -0.007488  0.004004 -0.063588
# 1  2024-01-04 -0.011432  0.010811 -0.008361 -0.012700  0.006232 -0.008003
# 2  2024-01-05  0.032123  0.038961  0.017028 -0.004013  0.004211 -0.007053
# 3  2024-01-08 -0.012449  0.072059  0.006339  0.024175 -0.004379  0.015617
# 4  2024-01-09  0.006618 -0.013717 -0.008399 -0.002263  0.005452  0.001437
#
#         ABM      ABNB       ABT  ...       WSM       WSO        WY       XEL  \
# 0 -0.020869 -0.007882 -0.003004  ... -0.043087 -0.024764 -0.020983  0.001733
# 1 -0.002304  0.002249  0.013331  ...  0.003290  0.008627 -0.013799  0.002359
# 2 -0.019630  0.016901 -0.001622  ...  0.004816 -0.016235  0.002679  0.000000
# 3  0.002120  0.030152  0.014440  ...  0.016723 -0.002241  0.010986 -0.002354
# 4 -0.009638 -0.003926  0.002936  ... -0.003460 -0.001234 -0.009104 -0.004876
#
#         XOM       XPO       XYL      YUMC       ZBH       ZTS
# 0  0.008402 -0.027097 -0.018563  0.012017 -0.007579 -0.018518
# 1 -0.008719 -0.006297  0.006902 -0.019558 -0.002241  0.005754
# 2  0.003030  0.002559 -0.001602 -0.028022 -0.001830  0.004174
# 3 -0.016662  0.013978  0.006242 -0.012949  0.016586  0.006672
# 4 -0.012386 -0.001079 -0.006557 -0.030693 -0.000820 -0.001071
#
# [5 rows x 445 columns]

# %% [markdown]
# ## Section 3.1: Calculated Covariance Matrix
#
# The covariance matrix is a matrix which relates behaviors of one stock with that of another stock. The covariance between two assets \(i\) and \(j\) is:
#
# $$
# \text{cov}(R_i, R_j) = \frac{1}{T-1} \sum_{t=1}^{T} (R_{i,t} - \bar{R}_i)(R_{j,t} - \bar{R}_j)
# $$
#
# The covariance matrix for \(n\) assets is:
#
# $$
# \Sigma =
# \begin{bmatrix}
# \text{var}(R_1) & \text{cov}(R_1, R_2) & \dots & \text{cov}(R_1, R_n) \\
# \text{cov}(R_2, R_1) & \text{var}(R_2) & \dots & \text{cov}(R_2, R_n) \\
# \vdots & \vdots & \ddots & \vdots \\
# \text{cov}(R_n, R_1) & \text{cov}(R_n, R_2) & \dots & \text{var}(R_n)
# \end{bmatrix}
# $$
#
# Where:
#
# - \(R_{i,t}\) = return of asset \(i\) at time \(t\)
# - \(\bar{R}_i\) = mean return of asset \(i\)
# - \(T\) = total number of periods (trading days)
#
# For this test, the testing period is days within the fiscal year 2023 for which yfinance was able to pull close price data. We have already converted the value to a percentage return, reflective of the precentage increase (positive %) or decrease (negative %) from the previous day's closing price. The pandas library already has a .cov() function that we can call. However, we must first remove the "Date" column from the dataframe.

# %%
# calculate the average returns for each stock over a year

# drop the "Date" column
returns_2023.drop(columns=['Date'], inplace=True)
print(returns_2023.head())

# calculate the matrix
covMatrix_2023 = returns_2023.cov()
print(covMatrix_2023.head())


## new*** calculate the expected return (annualized)
all_returns = returns_2023.mean().to_frame()
print("NVDA" in all_returns.index)
# Out:
#          AA       AAL       AAP      AAPL      ABBV       ABG       ABM  \
# 0  0.012337  0.066719  0.002310  0.010314  0.008067  0.028916  0.006491
# 1  0.007977  0.029433  0.008361 -0.010605 -0.001222  0.005018  0.014454
# 2  0.019125  0.013581  0.005615  0.036794  0.018717  0.022137  0.012933
# 3  0.084340  0.030324 -0.011427  0.004089 -0.029360  0.000054 -0.014499
# 4  0.053909  0.039699 -0.001905  0.004456 -0.012495  0.027844  0.014273
#
#        ABNB       ABT       ACI  ...       WSM       WSO        WY       XEL  \
# 0  0.044994  0.014875  0.009662  ...  0.035943  0.020205  0.011990  0.008563
# 1 -0.011384 -0.003687 -0.002392  ... -0.011509 -0.018001 -0.029779 -0.020235
# 2  0.009235  0.013809 -0.001918  ...  0.059498  0.025249  0.043234  0.029607
# 3  0.008134 -0.001602  0.005286  ... -0.012847  0.008959 -0.006011  0.009679
# 4 -0.007844  0.015158  0.018165  ...  0.028976  0.026600 -0.017823  0.001806
#
#         XOM       XPO       XYL      YUMC       ZBH       ZTS
# 0  0.002910  0.032458 -0.001535  0.039525  0.009271  0.014368
# 1  0.022374  0.018263 -0.028393 -0.010401 -0.018527 -0.023564
# 2  0.012087  0.058218  0.035551 -0.000345 -0.003014  0.015057
# 3 -0.018638  0.041400  0.004673  0.016029  0.002784 -0.003928
# 4  0.014935 -0.004803  0.010287  0.003732 -0.004363  0.049640
#
# [5 rows x 444 columns]
#             AA       AAL       AAP          AAPL          ABBV       ABG  \
# AA    0.001077  0.000315  0.000358  1.071807e-04  4.515133e-06  0.000384
# AAL   0.000315  0.000494  0.000177  7.906543e-05 -1.265128e-05  0.000245
# AAP   0.000358  0.000177  0.001057  6.005367e-05  1.199065e-05  0.000322
# AAPL  0.000107  0.000079  0.000060  1.580061e-04 -5.119259e-07  0.000091
# ABBV  0.000005 -0.000013  0.000012 -5.119259e-07  1.526833e-04 -0.000002
#
#            ABM      ABNB       ABT       ACI  ...       WSM       WSO  \
# AA    0.000197  0.000332  0.000075  0.000045  ...  0.000237  0.000225
# AAL   0.000101  0.000278  0.000042  0.000018  ...  0.000135  0.000125
# AAP   0.000185  0.000158  0.000061  0.000014  ...  0.000205  0.000151
# AAPL  0.000069  0.000124  0.000036  0.000008  ...  0.000094  0.000086
# ABBV  0.000019 -0.000008  0.000036  0.000005  ...  0.000015  0.000013
#
#             WY       XEL       XOM       XPO       XYL      YUMC       ZBH  \
# AA    0.000236  0.000042  0.000182  0.000323  0.000188  0.000249  0.000114
# AAL   0.000148  0.000006  0.000037  0.000228  0.000113  0.000059  0.000060
# AAP   0.000151  0.000050  0.000084  0.000198  0.000060  0.000058  0.000048
# AAPL  0.000069  0.000028  0.000020  0.000078  0.000063  0.000030  0.000041
# ABBV  0.000018  0.000038  0.000029  0.000001  0.000021  0.000009  0.000033
#
#            ZTS
# AA    0.000169
# AAL   0.000111
# AAP   0.000078
# AAPL  0.000076
# ABBV  0.000023
#
# [5 rows x 444 columns]
# True

# %% [markdown]
# ## Section 3.2: Application of Modern Portfolio Theory (MPT) Mathematical Approach

# %%
"""
Risk-Minimizing Portfolio for a Target Return
==============================================
Workflow:
  1. Load your full covariance matrix (all stocks)
  2. Pick any subset of tickers
  3. Call min_risk_target_return() — it slices the sub-matrix automatically
"""

import numpy as np
import pandas as pd
from scipy.optimize import minimize


def min_risk_target_return(
    full_cov_matrix: pd.DataFrame,
    expected_returns: pd.Series,
    selected_tickers: list,
    target_return: float,
    allow_short: bool = False,
) -> dict:
    """
    Slice the covariance matrix to only the selected tickers, then find
    the minimum-risk portfolio that achieves the target return.

    Parameters
    ----------
    full_cov_matrix  : pd.DataFrame — your complete N×N covariance matrix
    expected_returns : pd.Series    — annualised mean return per ticker (all stocks)
    selected_tickers : list         — tickers you want in this portfolio
    target_return    : float        — desired annualised return (e.g. 0.10 for 10%)
    allow_short      : bool         — allow negative weights (default False)

    Returns
    -------
    dict with keys:
        "weights"          pd.Series  — optimal weight per selected ticker
        "expected_return"  float
        "volatility"       float
        "variance"         float
        "cov_matrix_used"  pd.DataFrame — the sub-matrix actually used
    """

    # ── 1. Validate selected tickers exist in the full matrix ─────────────
    missing_cov = [t for t in selected_tickers if t not in full_cov_matrix.columns]
    missing_ret = [t for t in selected_tickers if t not in expected_returns.index]

    if missing_cov:
        raise ValueError(f"These tickers are not in the covariance matrix: {missing_cov}")
    if missing_ret:
        raise ValueError(f"These tickers have no expected return: {missing_ret}")

    # ── 2. Slice the sub-covariance matrix 
    #       This is the core fix — extract only the rows AND columns for the
    #       selected tickers, preserving their covariance relationships.
    cov_matrix = full_cov_matrix.loc[selected_tickers, selected_tickers]

    # ── 3. Validate the sliced matrix 
    if cov_matrix.isnull().any().any():
        bad = cov_matrix.columns[cov_matrix.isnull().any()].tolist()
        raise ValueError(f"Sub-matrix has NaN values for tickers: {bad}")

    zero_diag = [t for t in selected_tickers if cov_matrix.loc[t, t] == 0]
    if zero_diag:
        raise ValueError(f"Zero variance (diagonal) for tickers: {zero_diag}")

    # ── 4. Align expected returns to selected tickers 
    mu    = expected_returns.reindex(selected_tickers).values.astype(float)
    Sigma = cov_matrix.values.astype(float)
    n     = len(selected_tickers)

    # ── 5. Check target return is achievable
    mu_min = _min_var_return(Sigma, mu, n, allow_short)
    mu_max = float(mu.max())

    if not (mu_min - 1e-8 <= target_return <= mu_max + 1e-8):
        raise ValueError(
            f"\ntarget_return={target_return:.4%} is outside the achievable range "
            f"for {selected_tickers}.\n"
            f"  Min (global min-variance portfolio) : {mu_min:.4%}\n"
            f"  Max (best single asset)             : {mu_max:.4%}"
        )

    # ── 6. Optimise ───────────────────────────────────────────────────────
    constraints = [
        {"type": "eq", "fun": lambda w: float(w.sum() - 1.0)},
        {"type": "eq", "fun": lambda w: float(w @ mu - target_return)},
    ]
    bounds = [(-1.0, 1.0) if allow_short else (0.0, 1.0)] * n

    result = minimize(
        fun=lambda w: float(w @ Sigma @ w),
        x0=np.ones(n) / n,
        method="SLSQP",
        bounds=bounds,
        constraints=constraints,
        options={"ftol": 1e-12, "maxiter": 1000},
    )

    if not result.success:
        raise RuntimeError(f"Optimiser failed: {result.message}")

    # ── 7. Package results ────────────────────────────────────────────────
    w_opt = result.x.copy()
    w_opt[np.abs(w_opt) < 1e-6] = 0.0

    variance   = float(w_opt @ Sigma @ w_opt)
    volatility = float(np.sqrt(variance))

    return {
        "weights":         pd.Series(w_opt, index=selected_tickers, name="weights"),
        "expected_return": float(w_opt @ mu),
        "volatility":      volatility,
        "variance":        variance,
        "cov_matrix_used": cov_matrix,   # inspect this to confirm correct slicing
    }


def _min_var_return(Sigma, mu, n, allow_short):
    res = minimize(
        fun=lambda w: float(w @ Sigma @ w),
        x0=np.ones(n) / n,
        method="SLSQP",
        bounds=[(-1.0, 1.0) if allow_short else (0.0, 1.0)] * n,
        constraints=[{"type": "eq", "fun": lambda w: float(w.sum() - 1.0)}],
        options={"ftol": 1e-12, "maxiter": 1000},
    )
    return float(res.x @ mu)


my_stocks = ["AAPL", "NVDA", "AMZN"]
result = min_risk_target_return(
    full_cov_matrix  = covMatrix_2023,   # your N×N DataFrame
    expected_returns = all_returns,        # your Series of returns
    selected_tickers = my_stocks,          # your list of tickers
    target_return    = 0.003,               # your target as a decimal
)
print(result)



# DEMO BELOW (does not count)

# if __name__ == "__main__":

#     # Simulated full covariance matrix (replace with your real one)
#     all_tickers = ["AA", "AAL", "AAP", "AAPL", "ABBV", "AMZN", "HOOD", "META", "TSLA"]

#     np.random.seed(42)
#     rand = np.random.randn(len(all_tickers), len(all_tickers))
#     fake_cov = (rand @ rand.T) * 1e-4
#     full_cov_matrix = pd.DataFrame(fake_cov, index=all_tickers, columns=all_tickers)

#     all_returns = pd.Series({
#         "AA":   0.08, "AAL":  0.12, "AAP":  0.07, "AAPL": 0.15,
#         "ABBV": 0.06, "AMZN": 0.14, "HOOD": 0.18, "META": 0.20, "TSLA": 0.22,
#     })

#     # ── Choose any subset of stocks here ─────────────────────────────────
#     my_stocks = ["AMZN", "HOOD", "META", "AAPL", "TSLA"]

#     result = min_risk_target_return(
#         full_cov_matrix  = full_cov_matrix,
#         expected_returns = all_returns,
#         selected_tickers = my_stocks,
#         target_return    = 0.17,
#     )

#     print(f"\n{'─'*42}")
#     print(f"  Stocks selected  : {my_stocks}")
#     print(f"{'─'*42}")
#     print(f"  Achieved Return  : {result['expected_return']:.4%}")
#     print(f"  Volatility (σ)   : {result['volatility']:.4%}")
#     print(f"  Variance   (σ²)  : {result['variance']:.6f}")
#     print(f"{'─'*42}")
#     print("  Weights:")
#     for ticker, w in result["weights"].items():
#         bar = "█" * int(w * 40)
#         print(f"    {ticker:<6} {w:>7.2%}  {bar}")
#     print(f"{'─'*42}")
#     print(f"  Weights sum to   : {result['weights'].sum():.6f}")

#     print(f"\n  Sub-covariance matrix used ({len(my_stocks)}×{len(my_stocks)}):")
#     print(result["cov_matrix_used"].round(6))
# Out:
# {'weights': AAPL    0.550264
# NVDA    0.293757
# AMZN    0.155979
# Name: weights, dtype: float64, 'expected_return': 0.0029999999999999996, 'volatility': 0.015360006576229476, 'variance': 0.00023592980202181277, 'cov_matrix_used':           AAPL      NVDA      AMZN
# AAPL  0.000158  0.000171  0.000116
# NVDA  0.000171  0.000932  0.000242
# AMZN  0.000116  0.000242  0.000433}
# /var/folders/5_/hy9lx4ss2ldcv_gy3dt0s5qw0000gn/T/ipykernel_81116/2844340014.py:128: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return float(res.x @ mu)
# /var/folders/5_/hy9lx4ss2ldcv_gy3dt0s5qw0000gn/T/ipykernel_81116/2844340014.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   {"type": "eq", "fun": lambda w: float(w @ mu - target_return)},
# /var/folders/5_/hy9lx4ss2ldcv_gy3dt0s5qw0000gn/T/ipykernel_81116/2844340014.py:112: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   "expected_return": float(w_opt @ mu),

# %%
Let us visualize the behavior of a stock that has a very positive (closet to +1) covariance and one that is very negative (close to -1).

# %%
import numpy as np
import matplotlib.pyplot as plt

# search for the highest and lowest covariance values

# Copy the covariance matrix so diagonals can be masked
copyCovMatrix = covMatrix_2023.copy()
np.fill_diagonal(copyCovMatrix.values, np.nan)  # mask diagonal

# Flatten the matrix
flat_values = copyCovMatrix.values.flatten()

# Maximum off-diagonal covariance
maxCov = np.nanmax(flat_values)
row_idx, col_idx = np.unravel_index(np.nanargmax(copyCovMatrix.values), copyCovMatrix.shape)
row_label = copyCovMatrix.index[row_idx]
col_label = copyCovMatrix.columns[col_idx]
print(f"Max value: {maxCov}, row: {row_label}, column: {col_label}")

# Minimum off-diagonal covariance
minCov = np.nanmin(flat_values)
row_idx, col_idx = np.unravel_index(np.nanargmin(copyCovMatrix.values), copyCovMatrix.shape)
row_label = copyCovMatrix.index[row_idx]
col_label = copyCovMatrix.columns[col_idx]
print(f"Min value: {minCov}, row: {row_label}, column: {col_label}")

# graph

returns_2023 = pd.read_csv("returns_2023.csv") # read data again so we get the "Date" column back
returns_2024 = pd.read_csv("returns_2024.csv")

plt.figure(figsize=(10, 5))
plt.plot(returns_2023["Date"], returns_2023["FMCC"], label="FMCC", linewidth=1, alpha=0.6, color='red')
plt.plot(returns_2023["Date"], returns_2023["FNMA"], label="FNMA", linewidth=1, alpha=0.4, color='green')

plt.xlabel("Date")
plt.ylabel("Returns") 
plt.title("FMCC vs FNMA Returns (2023)")
plt.legend()
plt.xticks(returns_2023["Date"].iloc[::20], rotation=45)
# plt.grid(True)
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(returns_2023["Date"], returns_2023["IEP"], label="IEP", linewidth=1, alpha=0.6, color='orange')
plt.plot(returns_2023["Date"], returns_2023["SMCI"], label="SMCI", linewidth=1, alpha=0.3, color='blue')

plt.xlabel("Date")
plt.ylabel("Returns")  
plt.title("IEP vs SMCI Returns (2023)")
plt.legend()
plt.xticks(returns_2023["Date"].iloc[::20], rotation=45)
# plt.grid(True)
plt.show()
# Out:
# Max value: 0.0022696232840715277, row: FMCC, column: FNMA
# Min value: -0.000305362139174174, row: IEP, column: SMCI
